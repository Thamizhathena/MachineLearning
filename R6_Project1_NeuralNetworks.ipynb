# %% [markdown]
# Bank Customer Churn Modeling

# %% [markdown]
# ###**Connecting Drive with Colab**

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ###**Load Key Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %matplotlib inline
sns.set_style('whitegrid')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
tf.reset_default_graph()
tf.set_random_seed(40)

# %% [markdown]
# Read the dataset

# %%
#read data

bank_df = pd.read_csv('/content/gdrive/My Drive/bank.csv')
bank_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
bank_df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
Geo = pd.get_dummies(bank_df['Geography'],prefix = "Geo",prefix_sep = "_",drop_first = True)
bank_df.drop(['Geography'],axis = 1,inplace = True)
bank_df = pd.concat([bank_df,Geo],axis=1)

# %%
bank_df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
labelencoder = LabelEncoder()
bank_df['Gender'] = labelencoder.fit_transform(bank_df['Gender'])

# %%
bank_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619       0   42       2
# 1          2    15647311      Hill          608       0   41       1
# 2          3    15619304      Onio          502       0   42       8
# 3          4    15701354      Boni          699       0   39       1
# 4          5    15737888  Mitchell          850       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  Geo_Germany  Geo_Spain
# 0       1            0          0
# 1       0            0          1
# 2       1            0          0
# 3       0            0          0
# 4       0            0          1

# %% [markdown]
# Drop the columns which are unique for all users like IDs

# %%
bank_df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Geo_Germany', 'Geo_Spain'],
#       dtype='object')

# %%
bank_df.drop(['RowNumber', 'CustomerId','Surname'], axis=1, inplace = True)

# %%
bank_df.head(5)
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geo_Germany  Geo_Spain
# 0               1        101348.88       1            0          0
# 1               1        112542.58       0            0          1
# 2               0        113931.57       1            0          0
# 3               0         93826.63       0            0          0
# 4               1         79084.10       0            0          1

# %% [markdown]
# Distinguish the feature and target set

# %%
X = bank_df[['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
       'HasCrCard', 'IsActiveMember', 'EstimatedSalary','Geo_Germany', 'Geo_Spain']]

Y = bank_df['Exited']

# %% [markdown]
# Divide the data set into Train and test sets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (7000, 11)
# (3000, 11)
# (7000,)
# (3000,)

# %% [markdown]
# Normalize the train and test data

# %% [markdown]
# Initialize and build the model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.BatchNormalization(input_shape=(11,)))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,          
          validation_data=(X_test,Y_test),
          epochs=50)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1
# 7000/7000 [==============================] - 1s 135us/sample - loss: 0.4266 - acc: 0.8119 - val_loss: 0.4305 - val_acc: 0.8080
# Epoch 44/50
# 7000/7000 [==============================] - 1s 132us/sample - loss: 0.4264 - acc: 0.8131 - val_loss: 0.4306 - val_acc: 0.8083
# Epoch 45/50
# 7000/7000 [==============================] - 1s 134us/sample - loss: 0.4261 - acc: 0.8160 - val_loss: 0.4306 - val_acc: 0.8083
# Epoch 46/50
# 7000/7000 [==============================] - 1s 130us/sample - loss: 0.4282 - acc: 0.8133 - val_loss: 0.4306 - val_acc: 0.8080
# Epoch 47/50
# 7000/7000 [==============================] - 1s 130us/sample - loss: 0.4265 - acc: 0.8126 - val_loss: 0.4309 - val_acc: 0.8070
# Epoch 48/50
# 7000/7000 [==============================] - 1s 133us/sample - loss: 0.4285 - acc: 0.8120 - val_loss: 0.4306 - val_acc: 0.8083
# Epoch 49/50
# 7000/7000 [==============================] - 1s 133us/sample - loss: 0.4250 - acc: 0.8127 - val_loss: 0.4305 - val_acc: 0.8087
# Epoch 50/50
# 7000/7000 [==============================] - 1s 133us/sample - loss: 0.4273 - acc: 0.8147 - val_loss: 0.4308 - val_acc: 0.8090

# %%
Y_pred = model.predict(X_test)
Y_pred=Y_pred>0.50

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[2303,   73],
#        [ 500,  124]])

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.809

# %% [markdown]
# Optimize the model

# %%
model_nn = tf.keras.models.Sequential()

model_nn.add(tf.keras.layers.BatchNormalization(input_shape=(11,)))

model_nn.add(tf.keras.layers.Dense(10, activation='sigmoid'))

model_nn.add(tf.keras.layers.Dense(6, activation='sigmoid'))

model_nn.add(tf.keras.layers.Dense(4, activation='sigmoid'))

model_nn.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model_nn.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_nn.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_v1_3 (Ba (None, 11)                44
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 66
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 263
# Trainable params: 241
# Non-trainable params: 22
# _________________________________________________________________

# %%
model_nn.fit(X_train,Y_train,          
          validation_data=(X_test,Y_test), 
          epochs=50,
          batch_size=30)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/50
# 7000/7000 [==============================] - 1s 189us/sample - loss: 0.6100 - acc: 0.6863 - val_loss: 0.5263 - val_acc: 0.7920
# Epoch 2/50
# 7000/7000 [==============================] - 1s 161us/sample - loss: 0.5095 - acc: 0.7981 - val_loss: 0.5119 - val_acc: 0.7920
# Epoch 3/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5034 - acc: 0.7981 - val_loss: 0.5110 - val_acc: 0.7920
# Epoch 4/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5028 - acc: 0.7981 - val_loss: 0.5111 - val_acc: 0.7920
# Epoch 5/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5028 - acc: 0.7981 - val_loss: 0.5110 - val_acc: 0.7920
# Epoch 6/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5027 - acc: 0.7981 - val_loss: 0.5110 - val_acc: 0.7920
# 7000/7000 [==============================] - 1s 162us/sample - loss: 0.5019 - acc: 0.7981 - val_loss: 0.5102 - val_acc: 0.7920
# Epoch 28/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5020 - acc: 0.7981 - val_loss: 0.5102 - val_acc: 0.7920
# Epoch 29/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5020 - acc: 0.7981 - val_loss: 0.5102 - val_acc: 0.7920
# Epoch 30/50
# 7000/7000 [==============================] - 1s 162us/sample - loss: 0.5019 - acc: 0.7981 - val_loss: 0.5102 - val_acc: 0.7920
# Epoch 31/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5018 - acc: 0.7981 - val_loss: 0.5102 - val_acc: 0.7920
# Epoch 32/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5018 - acc: 0.7981 - val_loss: 0.5101 - val_acc: 0.7920
# Epoch 33/50
# 7000/7000 [==============================] - 1s 162us/sample - loss: 0.5017 - acc: 0.7981 - val_loss: 0.5101 - val_acc: 0.7920
# Epoch 34/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.5017 - acc: 0.7981 - val_loss: 0.5100 - val_acc: 0.7920
# Epoch 35/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5016 - acc: 0.7981 - val_loss: 0.5100 - val_acc: 0.7920
# Epoch 36/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5016 - acc: 0.7981 - val_loss: 0.5099 - val_acc: 0.7920
# Epoch 37/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5016 - acc: 0.7981 - val_loss: 0.5099 - val_acc: 0.7920
# Epoch 38/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5015 - acc: 0.7981 - val_loss: 0.5098 - val_acc: 0.7920
# Epoch 39/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5015 - acc: 0.7981 - val_loss: 0.5098 - val_acc: 0.7920
# Epoch 40/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5014 - acc: 0.7981 - val_loss: 0.5097 - val_acc: 0.7920
# Epoch 41/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5013 - acc: 0.7981 - val_loss: 0.5096 - val_acc: 0.7920
# Epoch 42/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5013 - acc: 0.7981 - val_loss: 0.5095 - val_acc: 0.7920
# Epoch 43/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5012 - acc: 0.7981 - val_loss: 0.5094 - val_acc: 0.7920
# Epoch 44/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5012 - acc: 0.7981 - val_loss: 0.5094 - val_acc: 0.7920
# Epoch 45/50
# 7000/7000 [==============================] - 1s 162us/sample - loss: 0.5011 - acc: 0.7981 - val_loss: 0.5094 - val_acc: 0.7920
# Epoch 46/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5010 - acc: 0.7981 - val_loss: 0.5093 - val_acc: 0.7920
# Epoch 47/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5010 - acc: 0.7981 - val_loss: 0.5092 - val_acc: 0.7920
# Epoch 48/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5009 - acc: 0.7981 - val_loss: 0.5092 - val_acc: 0.7920
# Epoch 49/50
# 7000/7000 [==============================] - 1s 161us/sample - loss: 0.5008 - acc: 0.7981 - val_loss: 0.5090 - val_acc: 0.7920
# Epoch 50/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5007 - acc: 0.7981 - val_loss: 0.5090 - val_acc: 0.7920

# %%
Y_pred = model_nn.predict(X_test)
Y_pred = Y_pred>0.50

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[2376,    0],
#        [ 624,    0]])

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.792

# %% [markdown]
# Optimize with SGD

# %%
model_nn = tf.keras.models.Sequential()

model_nn.add(tf.keras.layers.BatchNormalization(input_shape=(11,)))

model_nn.add(tf.keras.layers.Dense(10, activation='sigmoid'))

model_nn.add(tf.keras.layers.Dense(6, activation='sigmoid'))

model_nn.add(tf.keras.layers.Dense(4, activation='sigmoid'))

model_nn.add(tf.keras.layers.Dense(1, activation='sigmoid'))

sgd_optimizer = tf.keras.optimizers.SGD(lr=0.03)

model_nn.compile(optimizer= sgd_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_nn.fit(X_train,Y_train,          
          validation_data=(X_test,Y_test), 
          epochs=50,
          batch_size=30)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/50
# 7000/7000 [==============================] - 1s 201us/sample - loss: 0.5383 - acc: 0.7820 - val_loss: 0.5126 - val_acc: 0.7920
# Epoch 2/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5041 - acc: 0.7981 - val_loss: 0.5121 - val_acc: 0.7920
# Epoch 3/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5038 - acc: 0.7981 - val_loss: 0.5120 - val_acc: 0.7920
# Epoch 4/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5037 - acc: 0.7981 - val_loss: 0.5120 - val_acc: 0.7920
# Epoch 5/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5035 - acc: 0.7981 - val_loss: 0.5116 - val_acc: 0.7920
# Epoch 6/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5033 - acc: 0.7981 - val_loss: 0.5115 - val_acc: 0.7920
# Epoch 7/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5031 - acc: 0.7981 - val_loss: 0.5115 - val_acc: 0.7920
# Epoch 8/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5031 - acc: 0.7981 - val_loss: 0.5113 - val_acc: 0.7920
# Epoch 9/50
# 7000/7000 [==============================] - 1s 163us/sample - loss: 0.5029 - acc: 0.7981 - val_loss: 0.5112 - val_acc: 0.7920
# Epoch 10/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5027 - acc: 0.7981 - val_loss: 0.5113 - val_acc: 0.7920
# Epoch 11/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5027 - acc: 0.7981 - val_loss: 0.5108 - val_acc: 0.7920
# Epoch 12/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.5025 - acc: 0.7981 - val_loss: 0.5108 - val_acc: 0.7920
# Epoch 13/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5024 - acc: 0.7981 - val_loss: 0.5105 - val_acc: 0.7920
# Epoch 14/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5022 - acc: 0.7981 - val_loss: 0.5105 - val_acc: 0.7920
# Epoch 15/50
# 7000/7000 [==============================] - 1s 168us/sample - loss: 0.5021 - acc: 0.7981 - val_loss: 0.5101 - val_acc: 0.7920
# Epoch 16/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5020 - acc: 0.7981 - val_loss: 0.5099 - val_acc: 0.7920
# Epoch 17/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.5018 - acc: 0.7981 - val_loss: 0.5098 - val_acc: 0.7920
# Epoch 18/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5016 - acc: 0.7981 - val_loss: 0.5096 - val_acc: 0.7920
# Epoch 19/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5014 - acc: 0.7981 - val_loss: 0.5093 - val_acc: 0.7920
# Epoch 20/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.5013 - acc: 0.7981 - val_loss: 0.5092 - val_acc: 0.7920
# Epoch 21/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.5011 - acc: 0.7981 - val_loss: 0.5090 - val_acc: 0.7920
# Epoch 22/50
# 7000/7000 [==============================] - 1s 169us/sample - loss: 0.5009 - acc: 0.7981 - val_loss: 0.5087 - val_acc: 0.7920
# Epoch 23/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5007 - acc: 0.7981 - val_loss: 0.5087 - val_acc: 0.7920
# Epoch 24/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.5005 - acc: 0.7981 - val_loss: 0.5084 - val_acc: 0.7920
# Epoch 25/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.5001 - acc: 0.7981 - val_loss: 0.5079 - val_acc: 0.7920
# Epoch 26/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.5001 - acc: 0.7981 - val_loss: 0.5078 - val_acc: 0.7920
# Epoch 27/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.4997 - acc: 0.7981 - val_loss: 0.5074 - val_acc: 0.7920
# Epoch 28/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4995 - acc: 0.7981 - val_loss: 0.5070 - val_acc: 0.7920
# Epoch 29/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4991 - acc: 0.7981 - val_loss: 0.5070 - val_acc: 0.7920
# Epoch 30/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.4988 - acc: 0.7981 - val_loss: 0.5063 - val_acc: 0.7920
# Epoch 31/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.4984 - acc: 0.7981 - val_loss: 0.5057 - val_acc: 0.7920
# Epoch 32/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.4981 - acc: 0.7981 - val_loss: 0.5056 - val_acc: 0.7920
# Epoch 33/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.4975 - acc: 0.7981 - val_loss: 0.5050 - val_acc: 0.7920
# Epoch 34/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.4971 - acc: 0.7981 - val_loss: 0.5045 - val_acc: 0.7920
# Epoch 35/50
# 7000/7000 [==============================] - 1s 164us/sample - loss: 0.4965 - acc: 0.7981 - val_loss: 0.5038 - val_acc: 0.7920
# Epoch 36/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.4959 - acc: 0.7981 - val_loss: 0.5030 - val_acc: 0.7920
# Epoch 37/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4953 - acc: 0.7981 - val_loss: 0.5023 - val_acc: 0.7920
# Epoch 38/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.4946 - acc: 0.7981 - val_loss: 0.5013 - val_acc: 0.7920
# Epoch 39/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4936 - acc: 0.7981 - val_loss: 0.5004 - val_acc: 0.7920
# Epoch 40/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4926 - acc: 0.7981 - val_loss: 0.4993 - val_acc: 0.7920
# Epoch 41/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.4918 - acc: 0.7981 - val_loss: 0.4979 - val_acc: 0.7920
# Epoch 42/50
# 7000/7000 [==============================] - 1s 168us/sample - loss: 0.4905 - acc: 0.7981 - val_loss: 0.4964 - val_acc: 0.7920
# Epoch 43/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.4890 - acc: 0.7981 - val_loss: 0.4948 - val_acc: 0.7920
# Epoch 44/50
# 7000/7000 [==============================] - 1s 165us/sample - loss: 0.4879 - acc: 0.7981 - val_loss: 0.4935 - val_acc: 0.7920
# Epoch 45/50
# 7000/7000 [==============================] - 1s 161us/sample - loss: 0.4860 - acc: 0.7981 - val_loss: 0.4910 - val_acc: 0.7920
# Epoch 46/50
# 7000/7000 [==============================] - 1s 168us/sample - loss: 0.4841 - acc: 0.7981 - val_loss: 0.4889 - val_acc: 0.7920
# Epoch 47/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.4819 - acc: 0.7981 - val_loss: 0.4861 - val_acc: 0.7920
# Epoch 48/50
# 7000/7000 [==============================] - 1s 167us/sample - loss: 0.4794 - acc: 0.7981 - val_loss: 0.4833 - val_acc: 0.7920
# Epoch 49/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4771 - acc: 0.7981 - val_loss: 0.4804 - val_acc: 0.7920
# Epoch 50/50
# 7000/7000 [==============================] - 1s 166us/sample - loss: 0.4729 - acc: 0.7981 - val_loss: 0.4764 - val_acc: 0.7920

# %%
Y_pred = model_nn.predict(X_test)
Y_pred = Y_pred>0.50

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[2376,    0],
#        [ 624,    0]])

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.792
